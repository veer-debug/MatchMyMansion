# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Banglore_phase-1.csv')

# %%
df.Banglore[0]
# Out:
# '<html lang="en" class="has-webp" data-iswebp="true"><head><style id="react-native-stylesheet"></style><meta http-equiv="Content-Type" content="text/html; charset=utf-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="referrer" content="strict-origin-when-cross-origin"><link href="https://static.99acres.com" rel="preconnect"><link href="https://static.99acres.com" rel="dns-prefetch"><link href="https://mediacdn.99acres.com" rel="preconnect"><link href="https://mediacdn.99acres.com" rel="dns-prefetch"><link href="https://fonts.gstatic.com" rel="preconnect"><link href="https://fonts.gstatic.com" rel="dns-prefetch"><link rel="stylesheet" type="text/css" id="__tealBannerCss__"><link rel="stylesheet" type="text/css" id="__recomCss__"><link rel="stylesheet" type="text/css" id="__topDealerCss__"><link href=" https://www.youtube.com/iframe_api" rel="preconnect"><link rel="preload" href="https://imagecdn.99acres.com/media1/23384/13/467693454M-1705472135536.jpg" as="image" fet
# ...
