# %%
import pandas as pd
data=pd.read_excel("../Datas/flats.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 data=pd.read_excel("../Datas/flats.xlsx")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/excel/_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
# ...

# %%
data
# Out:
#                                           property_name  ... property_id
# 0        5 Bedroom House for sale in Sector 70A Gurgaon  ...   K70037724
# 1      5 Bedroom House for sale in Sector 21A Faridabad  ...   E69288322
# 2      10 Bedroom House for sale in Sushant Lok Phase 1  ...   F69536898
# 3        21 Bedroom House for sale in Sector 54 Gurgaon  ...   R69483164
# 4      12 Bedroom House for sale in Sushant Lok Phase 1  ...   M69381272
# ...                                                 ...  ...         ...
# 1090                 3 Bedroom House for sale in Bissar  ...   W70221444
# 1091                 3 Bedroom House for sale in Bissar  ...         NaN
# 1092            8 Bedroom House for sale in DLF Phase 2  ...         NaN
# 1093  8 Bedroom House for sale in C Block Sushant Lo...  ...         NaN
# 1094      2 Bedroom House for sale in Sector 92 Gurgaon  ...         NaN
#
# [1095 rows x 21 columns]
