# %%
from datetime import date

# Get today's date
today = date.today()

# Print today's date
print("Today's date:", today)
type(today)
# Out:
# Today's date: 2024-05-23
# datetime.date

# %%
import pickle

# %%
with open('Jupiter_works/dataset/finel_df.pkl','rb') as file:
    df = pickle.load(file)

# %%
df.head(1)
# Out:
#   id property_type     sector price bedRoom bathroom balcony agePossession  \
# 0  1          flat  sector 89  0.95     2.0      2.0       2  New Property
#
#   built_up_area servant_room store_room furnishing_type luxury_category  \
# 0        1226.0          1.0        0.0     unfurnished             Low
#
#   floor_category                                                img  \
# 0      Mid Floor  https://www.99acres.com/5-bhk-bedroom-independ...
#
#             society                                       near_locatio
# 0  smart world gems  {'Genesis Hospital Sector 84': '2.2 Km', 'Dwar...

# %%
df.society.values[100]
# Out:
# array(['dlf the ultima'], dtype=object)

# %%
# Assuming 'furnishing_type' is a column in the DataFrame df
unique_values_furnishing = (df['furnishing_type']).unique()

print(unique_values_furnishing)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_41521/471389274.py in ?()
#       1 # Assuming 'furnishing_type' is a column in the DataFrame df
# ----> 2 unique_values_furnishing = (df['furnishing_type']).unique()
#       3
#       4 print(unique_values_furnishing)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
df=pd.read_csv('/home/veer/Desktop/Running_Projects/MatchMyMansion0/Jupiter_works/dataset/final_df.csv')

# %%
df.head()
# Out:
#    id property_type       sector  price  bedRoom  bathroom balcony  \
# 0   1          flat    sector 89   0.95      2.0       2.0       2
# 1   2          flat    sector 92   1.60      3.0       4.0      3+
# 2   3          flat  gwal pahari   7.50      4.0       4.0      3+
# 3   4          flat   sector 108   2.00      3.0       3.0      3+
# 4   5          flat   sector 102   1.90      3.0       4.0       3
#
#     agePossession  built_up_area  servant_room  store_room furnishing_type  \
# 0    New Property         1226.0           1.0         0.0     unfurnished
# 1  Relatively New         1615.0           1.0         0.0   semifurnished
# 2    New Property         4842.0           1.0         0.0   semifurnished
# 3  Relatively New         2116.0           1.0         0.0     unfurnished
# 4  Relatively New         1710.0           1.0         0.0     unfurnished
#
#   luxury_category floor_category  \
# 0             Low      Mid Floor
# 1            High      Mid Floor
# ...

# %%
df[df.society=='DLF The Primus']
# Out:
# Empty DataFrame
# Columns: [id, property_type, sector, price, bedRoom, bathroom, balcony, agePossession, built_up_area, servant_room, store_room, furnishing_type, luxury_category, floor_category, img, society, near_locatio]
# Index: []

# %%
df.id.values
# Out:
# array([   1,    2,    3, ..., 3552, 3553, 3554])

# %%
df[df['id']==5].society.dtype
# Out:
# dtype('O')

# %%
df.shape
# Out:
# (3554, 15)
